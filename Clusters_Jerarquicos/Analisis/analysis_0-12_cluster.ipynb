# %% [markdown]
# # Analisis de los clusters para la sub muestra de 0 a 12 años

# %%
from IPython.display import display

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("infantes_clustered.csv")
df.head()
# Out:
#        estado       sexo vivo_o_muerto estado_localizado  edad  \
# 0      colima  masculino          vivo   no_especificado  12.0
# 1      colima  masculino          vivo   no_especificado   2.0
# 2  nuevo_leon   femenino          vivo   no_especificado   1.0
# 3  nuevo_leon   femenino          vivo   no_especificado  12.0
# 4  nuevo_leon  masculino          vivo   no_especificado   4.0
#
#       dias_busqueda  cluster
# 0  79 days, 0:00:00        0
# 1           0:00:00        0
# 2           0:00:00        1
# 3           0:00:00        1
# 4           0:00:00        0

# %%
df["cluster"].value_counts()
# Out:
# cluster
# 1    2187
# 0    1985
# 2    1244
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8, 8))

sns.set_palette("coolwarm")
sns.set_style("ticks")
sns.set_context("talk")

plt.ylabel('Frequency')
plt.xlabel('Cluster')
plt.title('Distribution of Cluster,0 to 12 age,all Mexico')

ax = sns.histplot(df.cluster, discrete='True')
ax.bar_label(ax.containers[0])

plt.show()

# %%
cero = df[df["cluster"] == 0].copy()
uno = df[df["cluster"] == 1].copy()
dos = df[df["cluster"] == 2].copy()

# %%
cero.head()
# Out:
#        estado       sexo vivo_o_muerto estado_localizado  edad  \
# 0      colima  masculino          vivo   no_especificado  12.0
# 1      colima  masculino          vivo   no_especificado   2.0
# 4  nuevo_leon  masculino          vivo   no_especificado   4.0
# 7   chihuahua  masculino          vivo         chihuahua  10.0
# 9     hidalgo  masculino          vivo           hidalgo   4.0
#
#        dias_busqueda  cluster
# 0   79 days, 0:00:00        0
# 1            0:00:00        0
# 4            0:00:00        0
# 7  122 days, 0:00:00        0
# 9   47 days, 0:00:00        0

# %%
cero.estado.value_counts()
# Out:
# estado
# guanajuato          474
# mexico              416
# chihuahua           136
# aguascalientes      111
# chiapas             103
# puebla               94
# sinaloa              72
# nuevo_leon           69
# queretaro            64
# colima               55
# baja_california      53
# ciudad_de_mexico     47
# hidalgo              44
# guerrero             38
# quintana_roo         35
# tamaulipas           34
# jalisco              24
# durango              17
# michoacan            17
# veracruz             14
# sonora               14
# oaxaca               12
# campeche             10
# morelos              10
# yucatan               8
# tlaxcala              6
# tabasco               3
# no_especificado       2
# coahuila              1
# nayarit               1
# zacatecas             1
# Name: count, dtype: int64

# %%
cero.estado_localizado.value_counts()
# Out:
# estado_localizado
# mexico                  386
# guanajuato              377
# no_especificado         217
# chihuahua               125
# aguascalientes          110
# chiapas                 100
# puebla                   88
# sinaloa                  67
# queretaro                64
# hidalgo                  43
# baja_california          41
# nuevo_leon               38
# guerrero                 36
# colima                   32
# quintana_roo             31
# distrito_federal         26
# tamaulipas               24
# veracruz                 24
# jalisco                  21
# michoacan                19
# sonora                   15
# durango                  15
# oaxaca                   12
# morelos                   8
# tlaxcala                  7
# yucatan                   6
# campeche                  5
# tabasco                   3
# san_luis_potosi           2
# baja_california_sur       1
# nayarit                   1
# coahuila_de_zaragoza      1
# zacatecas                 1
# Name: count, dtype: int64

# %%
cero.vivo_o_muerto.value_counts()
# Out:
# vivo_o_muerto
# vivo      1981
# muerto       4
# Name: count, dtype: int64

# %% [markdown]
# Aquí se identifica que el estatus de localización puede ser una variable importante para cada cluster

# %%
uno.vivo_o_muerto.value_counts()
# Out:
# vivo_o_muerto
# vivo    2187
# Name: count, dtype: int64

# %%
dos.vivo_o_muerto.value_counts()
# Out:
# vivo_o_muerto
# aun_sin_localizar    1221
# muerto                 23
# Name: count, dtype: int64

# %%
fig, axs = plt.subplots(1, 3,figsize=(25,8))

fig.suptitle('Estatus de localización x Clulster')

plotUno = sns.histplot(cero.vivo_o_muerto,ax=axs[0])
plotUno.bar_label(plotUno.containers[0])
axs[0].set_title('Cluster 0')

plotDos = sns.histplot(uno.vivo_o_muerto,ax=axs[1])
plotDos.bar_label(plotDos.containers[0])
axs[1].set_title('Cluster 1')

plotTres = sns.histplot(dos.vivo_o_muerto,ax=axs[2])
plotTres.bar_label(plotTres.containers[0])
axs[2].set_title('Cluster 2')
# Out:
# Text(0.5, 1.0, 'Cluster 2')

# %%
cero.edad.value_counts()
# Out:
# edad
# 12.0    392
# 11.0    266
# 10.0    202
# 2.0     157
# 9.0     155
# 1.0     128
# 4.0     124
# 3.0     123
# 6.0     117
# 8.0     112
# 7.0     110
# 5.0      99
# Name: count, dtype: int64

# %%
uno.edad.value_counts()
# Out:
# edad
# 12.0    737
# 11.0    229
# 1.0     164
# 2.0     137
# 3.0     136
# 10.0    123
# 9.0     117
# 7.0     116
# 5.0     116
# 6.0     107
# 8.0     106
# 4.0      99
# Name: count, dtype: int64

# %%
cero.sexo.value_counts()
# Out:
# sexo
# masculino    1985
# Name: count, dtype: int64

# %%
uno.sexo.value_counts()
# Out:
# sexo
# femenino    2187
# Name: count, dtype: int64

# %%
dos.sexo.value_counts()
# Out:
# sexo
# femenino     646
# masculino    598
# Name: count, dtype: int64

# %%
cero.edad.describe()
# Out:
# count    1985.000000
# mean        7.664987
# std         3.747191
# min         1.000000
# 25%         4.000000
# 50%         9.000000
# 75%        11.000000
# max        12.000000
# Name: edad, dtype: float64

# %%
uno.edad.describe()
# Out:
# count    2187.000000
# mean        8.125286
# std         3.941920
# min         1.000000
# 25%         5.000000
# 50%         9.000000
# 75%        12.000000
# max        12.000000
# Name: edad, dtype: float64

# %%
dos.edad.describe()
# Out:
# count    1244.000000
# mean        6.635852
# std         3.802658
# min         1.000000
# 25%         3.000000
# 50%         6.000000
# 75%        10.000000
# max        12.000000
# Name: edad, dtype: float64

# %%
sns.set_palette("coolwarm")
sns.set_style("ticks")
sns.set_context("talk")

ax = sns.catplot(data=df, x="cluster", y="edad", kind="box")

plt.show()

# %%
cero.dias_busqueda.describe()
# Out:
# count        1976
# unique        586
# top       0:00:00
# freq          369
# Name: dias_busqueda, dtype: object

# %%
uno.dias_busqueda.describe()
# Out:
# count        2168
# unique        624
# top       0:00:00
# freq          375
# Name: dias_busqueda, dtype: object

# %%
dos.dias_busqueda.describe()
# Out:
# count                     782
# unique                    443
# top       -6624 days, 0:00:00
# freq                        9
# Name: dias_busqueda, dtype: object

# %%
cero.dias_busqueda.value_counts()
# Out:
# dias_busqueda
# 0:00:00                369
# 1 day, 0:00:00         144
# 2 days, 0:00:00         61
# 31 days, 0:00:00        48
# 30 days, 0:00:00        47
#                       ...
# 452 days, 0:00:00        1
# -4282 days, 0:00:00      1
# -3678 days, 0:00:00      1
# -3356 days, 0:00:00      1
# 279 days, 0:00:00        1
# Name: count, Length: 586, dtype: int64

# %%
uno.dias_busqueda.value_counts()
# Out:
# dias_busqueda
# 0:00:00                375
# 1 day, 0:00:00         165
# 2 days, 0:00:00         74
# 31 days, 0:00:00        50
# 3 days, 0:00:00         42
#                       ...
# -4011 days, 0:00:00      1
# -216 days, 0:00:00       1
# 989 days, 0:00:00        1
# -256 days, 0:00:00       1
# -304 days, 0:00:00       1
# Name: count, Length: 624, dtype: int64

# %%
dos.dias_busqueda.value_counts()
# Out:
# dias_busqueda
# -6624 days, 0:00:00    9
# -6225 days, 0:00:00    7
# -6326 days, 0:00:00    6
# -6622 days, 0:00:00    6
# -6654 days, 0:00:00    6
#                       ..
# -6483 days, 0:00:00    1
# -5926 days, 0:00:00    1
# -5938 days, 0:00:00    1
# -6032 days, 0:00:00    1
# -6724 days, 0:00:00    1
# Name: count, Length: 443, dtype: int64

# %%
cero[cero["vivo_o_muerto"] == "muerto"]
# Out:
#           estado       sexo vivo_o_muerto estado_localizado  edad  \
# 1671  guanajuato  masculino        muerto        guanajuato  11.0
# 2487  guanajuato  masculino        muerto        guanajuato  10.0
# 3472  guanajuato  masculino        muerto        guanajuato  11.0
# 4137  guanajuato  masculino        muerto        guanajuato   3.0
#
#           dias_busqueda  cluster
# 1671    2 days, 0:00:00        0
# 2487   30 days, 0:00:00        0
# 3472  665 days, 0:00:00        0
# 4137  -41 days, 0:00:00        0

# %%
dos[["estado", "estado_localizado"]].value_counts()
# Out:
# estado            estado_localizado
# ciudad_de_mexico  no_especificado      28
# puebla            no_especificado      11
# michoacan         no_especificado       8
# hidalgo           no_especificado       7
# veracruz          no_especificado       7
# durango           no_especificado       5
# nuevo_leon        no_especificado       5
# sinaloa           sinaloa               4
# guerrero          guerrero              3
# mexico            oaxaca                3
# oaxaca            no_especificado       3
# chihuahua         no_especificado       2
# guerrero          no_especificado       2
# mexico            mexico                2
# sonora            sonora                2
# tamaulipas        no_especificado       2
#                   tamaulipas            2
# chihuahua         chihuahua             2
# mexico            no_especificado       1
# colima            colima                1
# puebla            puebla                1
# quintana_roo      no_especificado       1
# Name: count, dtype: int64

# %%
cero[["estado", "estado_localizado"]].value_counts()
# Out:
# estado          estado_localizado
# mexico          mexico               381
# guanajuato      guanajuato           367
# chihuahua       chihuahua            122
# aguascalientes  aguascalientes       109
# chiapas         chiapas               95
#                                     ...
# puebla          tlaxcala               1
# guanajuato      guerrero               1
# queretaro       chiapas                1
# jalisco         distrito_federal       1
# zacatecas       zacatecas              1
# Name: count, Length: 124, dtype: int64

# %%
uno[["estado", "estado_localizado"]].value_counts()
# Out:
# estado          estado_localizado
# mexico          mexico               439
# guanajuato      guanajuato           425
# aguascalientes  aguascalientes       146
# chiapas         chiapas               96
# puebla          puebla                84
#                                     ...
# durango         no_especificado        1
# puebla          guerrero               1
#                 nuevo_leon             1
#                 oaxaca                 1
#                 distrito_federal       1
# Name: count, Length: 122, dtype: int64

# %%
plt.figure(figsize=(20,10))

sns.set_style("ticks")
sns.set_context("talk")

plot_cero = sns.histplot(cero.estado, label='Cluster 0', alpha=0.5,linewidth=.8,discrete="true",color="#fe218b")
plot_uno = sns.histplot(uno.estado,label='Cluster 1', alpha=0.5,linewidth=.8,discrete="true",color="#fed700")
plot_dos = sns.histplot(dos.estado, label='Cluster 2', alpha=0.8,linewidth=.8,discrete="true", color="#21b0fe")

plot_cero.set_xticklabels(plot_cero.get_xticklabels(), rotation = 60)
plot_uno.set_xticklabels(plot_uno.get_xticklabels(), rotation = 60)
plot_dos.set_xticklabels(plot_dos.get_xticklabels(), rotation = 60)

plt.legend()

plt.ylabel('Frecuencia')
plt.xlabel('Estado')
plt.title('Estado x Cluster')

plt.show()
