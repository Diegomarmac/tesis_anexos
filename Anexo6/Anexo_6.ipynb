# %% [markdown]
# # CENAPI OVERVIEW

# %%
from IPython.display import display

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('data/cenapi.csv')

df.columns = df.columns.str.lower().str.replace(' ', '_')
string_columns = list(df.dtypes[df.dtypes == 'object'].index)
for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')
    
df.head()
# Out:
# C:\Users\Diego\AppData\Local\Temp\ipykernel_4068\1046732760.py:1: DtypeWarning: Columns (6,8,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/cenapi.csv')
#             x01            x02       x03            x04       x05       x06  \
# 0  desaparecido  12/10/11_0:00  10:30:00  09/02/09_0:00   2:30:00  tlaxcala
# 1  desaparecido  03/01/12_0:00  10:00:00  28/12/11_0:00  12:00:00    colima
# 2  desaparecido  19/12/11_0:00  11:20:00  17/12/11_0:00   9:00:00  tlaxcala
# 3  desaparecido  02/01/12_0:00  11:41:00  14/12/11_0:00  11:00:00    colima
# 4  desaparecido  06/01/12_0:00  12:00:00  05/01/12_0:00  11:15:00    colima
#
#   x07                       x08 x09       x10  ...  x66     x67  x68  x69  \
# 0  29                  tlaxcala  33  mexicana  ...  NaN     NaN  NaN  NaN
# 1   6          villa_de_alvarez  10  mexicana  ...  NaN     NaN  NaN  NaN
# 2  29  la_magdalena_tlaltelulco  48  mexicana  ...  NaN     NaN  NaN  NaN
# 3   6                   tecoman   9  mexicana  ...  NaN  grande  NaN  NaN
# 4   6          villa_de_alvarez  10  mexicana  ...  NaN     NaN  NaN  NaN
#
#                x70 x71                x72                        x73  \
# 0  no_especificado NaN  eventos_validados                          _
# 1  no_especificado NaN  eventos_validados                          _
# 2  no_especificado NaN  eventos_validados  ausencia_involuntaria____
# 3  no_especificado NaN  eventos_validados                          _
# 4  no_especificado NaN  eventos_validados                          _
#
#           x74 x75
# 0           _   _
# 1           _   _
# 2  accidentes   _
# 3           _   _
# 4           _   _
#
# [5 rows x 75 columns]

# %%
len(df)
# Out:
# 99129

# %% [markdown]
# ## Cantidad de desaparecidos por genero

# %%
df.x12.value_counts()
# Out:
# masculino    55941
# femenino     43187
# Name: x12, dtype: int64

# %%
plt.figure(figsize=(8, 8))

font1 = {'family':'sans-serif','color':'black','size':20}
font2 = {'family':'sans-serif','color':'black','size':15}

plt.ylabel('Frequency',fontdict=font2)
plt.xlabel('Gender',fontdict=font2)
plt.title('Distribution of gender', fontdict=font1)

sns.histplot(df.x12)
plt.show()

# %% [markdown]
# ## Estados donde fueron declarados desaparecidos

# %%
df.x06.value_counts() # esto es el estado de origen de los desaparecidos
# Out:
# guanajuato             13724
# mexico                 12097
# tamaulipas              9128
# sinaloa                 7798
# chihuahua               5836
# jalisco                 4682
# nuevo_leon              4599
# puebla                  4517
# baja_california         3699
# sonora                  3606
# ciudad_de_mexico        3521
# aguascalientes          2948
# guerrero                2515
# colima                  2454
# coahuila                2217
# chiapas                 2173
# michoacan               2134
# queretaro               1740
# quintana_roo            1389
# durango                 1275
# veracruz                1195
# morelos                 1095
# hidalgo                  907
# campeche                 785
# zacatecas                741
# tabasco                  706
# yucatan                  586
# oaxaca                   417
# nayarit                  162
# tlaxcala                 143
# no_especificado          138
# san_luis_potosi          137
# baja_california_sur       60
# texas                      2
# california                 1
# new_york                   1
# georgia                    1
# Name: x06, dtype: int64

# %%
plt.figure(figsize=(25, 10))

font1 = {'family':'sans-serif','color':'black','size':20}
font2 = {'family':'sans-serif','color':'black','size':15}

plt.ylabel('Frequency',fontdict=font2)
plt.xlabel('State', fontdict=font2)
plt.title('Distribution of Missing', fontdict=font1)


sns.histplot(df.x06,kde=True)
plt.show()

# %% [markdown]
# ## Conteo de encontrados y no encontrados

# %%
df.x38.value_counts()
# Out:
# vivo                 58643
# aun_sin_localizar    36693
# muerto                3793
# Name: x38, dtype: int64

# %%
plt.figure(figsize=(10, 10))

font1 = {'family':'sans-serif','color':'black','size':20}
font2 = {'family':'sans-serif','color':'black','size':15}

plt.ylabel('Frequency',fontdict=font2)
plt.xlabel('Located ?', fontdict=font2)
plt.title('Distribution of (non)located', fontdict=font1)


sns.histplot(df.x38)
plt.show()

# %% [markdown]
# ## Conteo por ocupación

# %%
df.x23.value_counts()
# Out:
# no_especificado        33493
# estudiante             13019
# empleado_particular     8205
# desempleado             5868
# sin_dato                3579
#                        ...
# maletero                   1
# juez                       1
# checador_de_taxi           1
# ex-comandante              1
# remero                     1
# Name: x23, Length: 150, dtype: int64
